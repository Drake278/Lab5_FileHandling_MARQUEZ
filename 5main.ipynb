# %%
from pathlib import Path

student_id = "2025-0080"
student_name = "Marquez"

# This targets your Lab5_FileHandling_MARQUEZ folder
documents_path = Path.cwd() / "Activity_5_Files"
documents_path.mkdir(parents=True, exist_ok=True)

file_path = documents_path / f"intro_{student_id}.txt"
file_path.write_text(f"Welcome {student_name} (ID: {student_id}) to File Handling in Python!")

print(f"File created and text written at: {file_path}")
# Out:
# File created and text written at: c:\COMPROG projects\CMPRG_!B\Lab5_FileHandling_MARQUEZ\Activity_5_Files\intro_2025-0080.txt

# %%
from pathlib import Path

student_id = "2025-0080"


documents_path = Path.cwd() / "Activity_5_Files"
file_path = documents_path / f"intro_{student_id}.txt"

content = file_path.read_text()
print(content)
# Out:
# Welcome Marquez (ID: 2025-0080) to File Handling in Python!

# %%
from pathlib import Path

student_id = "2025-0080"


file_path = Path.cwd() / "Activity_5_Files" / f"intro_{student_id}.txt"

with file_path.open("a") as f:
    f.write("\nThis is a new line.")

print(f"Line appended to: {file_path}")
# Out:
# Line appended to: c:\COMPROG projects\CMPRG_!B\Lab5_FileHandling_MARQUEZ\Activity_5_Files\intro_2025-0080.txt

# %%
from pathlib import Path

student_id = "2025-0080"


documents_path = Path.cwd() / "Activity_5_Files"
file_path = documents_path / f"lines_{student_id}.txt"

lines = ["Line 1", "Line 2", "Line 3"]
with file_path.open("w") as f:
    f.write("\n".join(lines))

print(f"Multiple lines written to: {file_path}")
# Out:
# Multiple lines written to: c:\COMPROG projects\CMPRG_!B\Lab5_FileHandling_MARQUEZ\Activity_5_Files\lines_2025-0080.txt

# %%
from pathlib import Path

student_id = "2025-0080"


file_path = Path.cwd() / "Activity_5_Files" / f"lines_{student_id}.txt"

with file_path.open("r") as f:
    for line in f:
        print(line.strip())
# Out:
# Line 1
# Line 2
# Line 3

# %%
from pathlib import Path

student_id = "2025-0080"
student_name = "Marquez"


file_path = Path.cwd() / "Activity_5_Files" / f"intro_{student_id}.txt"

text = file_path.read_text()
word_count = len(text.split())

print(f"{student_name} (ID: {student_id}) - Word count in file '{file_path.name}': {word_count}")
# Out:
# Marquez (ID: 2025-0080) - Word count in file 'intro_2025-0080.txt': 14

# %%
import shutil
from pathlib import Path

student_id = "2025-0080"

documents_path = Path.cwd() / "Activity_5_Files"

# Define source and destination
src = documents_path / f"intro_{student_id}.txt"
dst = documents_path / f"intro_copy_{student_id}.txt"

# Copy file
shutil.copy(src, dst)
print(f"File copied successfully from {src.name} to {dst.name}.")
# Out:
# File copied successfully from intro_2025-0080.txt to intro_copy_2025-0080.txt.

# %%
from pathlib import Path

student_id = "2025-0080"

documents_path = Path.cwd() / "Activity_5_Files"

old_file = documents_path / f"intro_copy_{student_id}.txt"
new_file = documents_path / f"intro_renamed_{student_id}.txt"
old_file.rename(new_file)

print(f"File renamed successfully from {old_file.name} to {new_file.name}.")
# Out:
# File renamed successfully from intro_copy_2025-0080.txt to intro_renamed_2025-0080.txt.

# %%
from pathlib import Path

student_id = "2025-0080"

documents_path = Path.cwd() / "Activity_5_Files"
file_path = documents_path / f"intro_renamed_{student_id}.txt"

if file_path.exists():
    file_path.unlink()
    print(f"File deleted successfully from: {file_path}")
else:
    print(f"No file found to delete at: {file_path}")
# Out:
# File deleted successfully from: c:\COMPROG projects\CMPRG_!B\Lab5_FileHandling_MARQUEZ\Activity_5_Files\intro_renamed_2025-0080.txt

# %%
from pathlib import Path

student_id = "2025-0080"


documents_path = Path.cwd() / "Activity_5_Files"
new_dir = documents_path / f"data_{student_id}"


new_dir.mkdir(parents=True, exist_ok=True)

print(f"Subdirectory created at: {new_dir}")
# Out:
# Subdirectory created at: c:\COMPROG projects\CMPRG_!B\Lab5_FileHandling_MARQUEZ\Activity_5_Files\data_2025-0080

# %%
import json
from pathlib import Path

student_id = "2025-0080"

documents_path = Path.cwd() / "Activity_5_Files"
data_dir = documents_path / f"data_{student_id}"
data_dir.mkdir(parents=True, exist_ok=True)

data = {
    "name": "Marquez", 
    "age": 18, 
    "course": "Engineering"
}

file_path = data_dir / f"student_{student_id}.json"
with file_path.open("w") as f:
    json.dump(data, f, indent=4)

print(f"JSON file written at: {file_path}")
# Out:
# JSON file written at: c:\COMPROG projects\CMPRG_!B\Lab5_FileHandling_MARQUEZ\Activity_5_Files\data_2025-0080\student_2025-0080.json

# %%
import json
from pathlib import Path

student_id = "2025-0080"


file_path = Path.cwd() / "Activity_5_Files" / f"data_{student_id}" / f"student_{student_id}.json"


with file_path.open("r") as f:
    data = json.load(f)

print(data)
# Out:
# {'name': 'Marquez', 'age': 18, 'course': 'Engineering'}

# %%
import csv
from pathlib import Path

student_id = "2025-0080"
student_name = "Marquez"

documents_path = Path.cwd() / "Activity_5_Files"
file_path = documents_path / f"students_{student_id}.csv"

rows = [
    ["Name", "Student ID", "Score"],
    ["Anna", "2025-1001", 90],
    ["Ben", "2025-1002", 85],
    [student_name, student_id, 95]
]


with file_path.open("w", newline='') as f:
    writer = csv.writer(f)
    writer.writerows(rows)

print(f"CSV file created at: {file_path}")
# Out:
# CSV file created at: c:\COMPROG projects\CMPRG_!B\Lab5_FileHandling_MARQUEZ\Activity_5_Files\students_2025-0080.csv

# %%
import csv
from pathlib import Path

student_id = "2025-0080"

file_path = Path.cwd() / "Activity_5_Files" / f"students_{student_id}.csv"

# Read and display CSV content
with file_path.open("r") as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Student ID', 'Score']
# ['Anna', '2025-1001', '90']
# ['Ben', '2025-1002', '85']
# ['Marquez', '2025-0080', '95']

# %%
from pathlib import Path

student_id = "2025-0080"


file_path = Path.cwd() / "Activity_5_Files" / f"missing_file_{student_id}.txt"

try:
    print(file_path.read_text())
except FileNotFoundError:
    print(f"File not found for Student ID: {student_id}")
# Out:
# File not found for Student ID: 2025-0080

# %%
from pathlib import Path

student_id = "2025-0080"

documents_path = Path.cwd() / "Activity_5_Files"


txt_files = list(documents_path.glob("*.txt"))


print(f"Student ID: {student_id}")
print(f"Found {len(txt_files)} .txt files in {documents_path}")
for file in txt_files:
    print(file.name)
# Out:
# Student ID: 2025-0080
# Found 2 .txt files in c:\COMPROG projects\CMPRG_!B\Lab5_FileHandling_MARQUEZ\Activity_5_Files
# intro_2025-0080.txt
# lines_2025-0080.txt

# %%
import os
import time
from pathlib import Path

student_id = "2025-0080"

file_path = Path.cwd() / "Activity_5_Files" / f"intro_{student_id}.txt"


if file_path.exists():
    stat = file_path.stat()
    print(f"Student ID: {student_id}")
    print(f"File: {file_path.name}")
    print(f"Size: {stat.st_size} bytes")
    print(f"Last Modified: {time.ctime(stat.st_mtime)}")
else:
    print(f"File {file_path.name} not found for Student ID: {student_id}")
# Out:
# Student ID: 2025-0080
# File: intro_2025-0080.txt
# Size: 80 bytes
# Last Modified: Sun Apr 26 00:02:57 2026

# %%
from pathlib import Path


student_id = "2025-0080"

# Define file path in your local folder
file_path = Path.cwd() / "Activity_5_Files" / f"lines_{student_id}.txt"

if not file_path.exists():
    sample_lines = ["Line 1", "Line 2", "Line 3"]
    file_path.write_text("\n".join(sample_lines))
    print(f"Sample file created for Student ID: {student_id}")

lines = file_path.read_text().splitlines()
with file_path.open("w") as f:
    for i, line in enumerate(lines, 1):
        f.write(f"{i}: {line.upper()}\n")

print(f"Lines formatted and updated in file: {file_path}")
# Out:
# Lines formatted and updated in file: c:\COMPROG projects\CMPRG_!B\Lab5_FileHandling_MARQUEZ\Activity_5_Files\lines_2025-0080.txt

# %%
from pathlib import Path


student_id = "2025-0080"

# Define file path targeting your local folder
file_path = Path.cwd() / "Activity_5_Files" / f"lines_{student_id}.txt"

if not file_path.exists():
    sample_lines = ["Line 1", "Line 2", "Line 3"]
    file_path.write_text("\n".join(sample_lines))
    print(f"Sample file created for Student ID: {student_id}")


lines = file_path.read_text().splitlines()
lines.reverse()

with file_path.open("w") as f:
    f.write("\n".join(lines))

print(f"File lines reversed for Student ID: {student_id}")
# Out:
# File lines reversed for Student ID: 2025-0080

# %%
from pathlib import Path


student_id = "2025-0080"


documents_path = Path.cwd() / "Activity_5_Files"

f1 = documents_path / f"intro_{student_id}.txt"
f2 = documents_path / f"lines_{student_id}.txt"
merged = documents_path / f"merged_{student_id}.txt"

if not f1.exists():
    f1.write_text(f"Welcome {student_id} to File Handling in Python!")
    print(f"Sample intro file created for Student ID: {student_id}")

if not f2.exists():
    f2.write_text("Line 1\nLine 2\nLine 3")
    print(f"Sample lines file created for Student ID: {student_id}")


with merged.open("w") as mf:
    mf.write(f1.read_text())
    mf.write("\n")
    mf.write(f2.read_text())

print(f"Files merged successfully for Student ID: {student_id}")
# Out:
# Files merged successfully for Student ID: 2025-0080
